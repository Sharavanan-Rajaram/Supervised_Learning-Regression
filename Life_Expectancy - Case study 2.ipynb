# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the data set  (Life Expectancy data)
#
# The dataset contains information about several health and economic factors that contribute to average life expectancy for different countries. <br> Attribute information:
#
# **Country:** Name of the country
#
# **Year:** Year the observations were recorded
#
# **Status:** Whether the country is Developed or Developing
#
# **Adult_Mortality:** Mortality rate for age group 15-60 out of every 1000 individuals of the population
#
# **Infant_Deaths:** Number of infant deaths per 1000 population
#
# **Alcohol:** Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
#
# **Hepatitis B:** Hepatitis B (HepB) immunization coverage for 1 year olds (Percentage)
#
# **Measles:** Number of reported cases for measles per 1000 from population
#
# **BMI:** Average Body Mass Index for entire population
#
# **Underfive_Deaths:** Number of deaths under 5 years of age per 1000 population
#
# **Polio:** Polio (Pol3) immunization coverage for 1 year olds (Percentage)
#
# **Diphtheria:** Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage for 1 year olds (Percentage)
#
# **HIV:** Deaths per 1000 live births due to HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Malnourished10_19:** Prevalence of malnutrition among children and adolescents for Age 10 to 19 (Percentage)
#
# **Malnourished5_9:** Prevalence of malnutrition among children for Age 5 to 9 (Percentage)
#
# **Income_Index:** Human Development Index (HDI) in terms of national income per capita (index ranging from 0 to 1)
#
# **Schooling:** Number of years of Schooling
#
# **Life_Expectancy:** Life Expectancy in age for the country

# %% [markdown]
# ##  Table of Content
#
# 1. **[Data Preparation](#eda)**
# 2. **[Linear Regression](#lf)**
# 3. **[Gradient Descent](#gd)**
# 4. **[Regularization](#reg)**
# 5. **[Grid Search](#gs)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the Life expectancy dataset and display the first five records

# %%
# load the csv file

# type your code here

# display the first five observations

# type your code here

data=pd.read_csv('Life_Expectancy-Day3.csv')
data.head()
# Out:
#        Country  Year      Status  Adult_Mortality  Infant_Deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1      Albania  2015  Developing             74.0              0     4.60
# 2      Algeria  2015  Developing             19.0             21      NaN
# 3       Angola  2015  Developing            335.0             66      NaN
# 4      Antigua  2015  Developing             13.0              0      NaN
#
#    Hepatitis B  Measles    BMI  Underfive_Deaths   Polio  Diphtheria   HIV  \
# 0         65.0      1154  19.1                 83      6           65  0.1
# 1         99.0         0  58.0                  0     99           99  0.1
# 2         95.0        63  59.5                 24     95           95  0.1
# 3         64.0       118  23.3                 98      7           64  1.9
# 4         99.0         0  47.7                  0     86           99  0.2
#
# ...

# %% [markdown]
# #### Check the shape of the data and display its information

# %%
# check the size of the dataframe

# type your code here

# %%
# display dataset information understand the dataset

# type your code here

# %%
data.isna().sum()
# Out:
# Country                0
# Year                   0
# Status                 0
# Adult_Mortality        9
# Infant_Deaths          0
# Alcohol              167
# Hepatitis B            9
# Measles                0
# BMI                    4
# Underfive_Deaths       0
# Polio                  0
# Diphtheria             0
# HIV                    0
# GDP                   25
# Population            41
# Malnourished10_19      4
# Malnourished5_9        4
# Income_Index          13
# Schooling              9
# Life_Expectancy        9
# dtype: int64

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="eda"> </a>
# ## 1. Data Preparation

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. The dataset gives the life expectancy for different countries. Check if any information about life expectancy is missing from the given records. How do we fix the problem if present?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

# %% [raw]
# In output column is where is Values misisng. we cant impute something to a variable which needs prediction, so better to drop nan values in it.

# %%
data1=data.dropna(subset=['Life_Expectancy'])

# %%
data1=data1.reset_index(drop=True)

#Do it whenever we do the drop. Drop=True else we may get new columns

# %%
data1.isna().sum()
# Out:
# Country                0
# Year                   0
# Status                 0
# Adult_Mortality        0
# Infant_Deaths          0
# Alcohol              166
# Hepatitis B            9
# Measles                0
# BMI                    2
# Underfive_Deaths       0
# Polio                  0
# Diphtheria             0
# HIV                    0
# GDP                   21
# Population            34
# Malnourished10_19      2
# Malnourished5_9        2
# Income_Index           7
# Schooling              7
# Life_Expectancy        0
# dtype: int64

# %%
# type your code here

data1.isna().sum()/len(data1)
# Out:
# Country              0.000000
# Year                 0.000000
# Status               0.000000
# Adult_Mortality      0.000000
# Infant_Deaths        0.000000
# Alcohol              0.959538
# Hepatitis B          0.052023
# Measles              0.000000
# BMI                  0.011561
# Underfive_Deaths     0.000000
# Polio                0.000000
# Diphtheria           0.000000
# HIV                  0.000000
# GDP                  0.121387
# Population           0.196532
# Malnourished10_19    0.011561
# Malnourished5_9      0.011561
# Income_Index         0.040462
# Schooling            0.040462
# Life_Expectancy      0.000000
# dtype: float64

# %%
data2=data1.drop('Alcohol',axis=1)

# %%
data2
# Out:
#          Country  Year      Status  Adult_Mortality  Infant_Deaths  \
# 0    Afghanistan  2015  Developing            263.0             62
# 1        Albania  2015  Developing             74.0              0
# 2        Algeria  2015  Developing             19.0             21
# 3         Angola  2015  Developing            335.0             66
# 4        Antigua  2015  Developing             13.0              0
# ..           ...   ...         ...              ...            ...
# 168    Venezuela  2015  Developing            157.0              9
# 169     Viet Nam  2015  Developing            127.0             28
# 170        Yemen  2015  Developing            224.0             37
# 171       Zambia  2015  Developing             33.0             27
# 172     Zimbabwe  2015  Developing            336.0             22
#
#      Hepatitis B  Measles    BMI  Underfive_Deaths   Polio  Diphtheria   HIV  \
# 0           65.0      1154  19.1                 83      6           65  0.1
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. How do we handle the missing values from the entire dataset?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data2=data2.drop('Country',1)

# %%
data2=pd.get_dummies(data2,drop_first=True)

# %%
data2
# Out:
#      Year  Adult_Mortality  Infant_Deaths  Hepatitis B  Measles    BMI  \
# 0    2015            263.0             62         65.0      1154  19.1
# 1    2015             74.0              0         99.0         0  58.0
# 2    2015             19.0             21         95.0        63  59.5
# 3    2015            335.0             66         64.0       118  23.3
# 4    2015             13.0              0         99.0         0  47.7
# ..    ...              ...            ...          ...       ...   ...
# 168  2015            157.0              9         87.0         0  62.1
# 169  2015            127.0             28         97.0       256  17.5
# 170  2015            224.0             37         69.0       468  41.3
# 171  2015             33.0             27          9.0         9  23.4
# 172  2015            336.0             22         87.0         0  31.8
#
#      Underfive_Deaths   Polio  Diphtheria   HIV           GDP  Population  \
# ...

# %%
data2['Year'].value_counts()

#Drop it - Much of representation like 172 data belongs to 172 and only one is 2013.
#so model wont learn anything form this
# Out:
# 2015    172
# 2013      1
# Name: Year, dtype: int64

# %%
data2=data2.drop('Year',1)
data2
# Out:
#      Adult_Mortality  Infant_Deaths  Hepatitis B  Measles    BMI  \
# 0              263.0             62         65.0      1154  19.1
# 1               74.0              0         99.0         0  58.0
# 2               19.0             21         95.0        63  59.5
# 3              335.0             66         64.0       118  23.3
# 4               13.0              0         99.0         0  47.7
# ..               ...            ...          ...       ...   ...
# 168            157.0              9         87.0         0  62.1
# 169            127.0             28         97.0       256  17.5
# 170            224.0             37         69.0       468  41.3
# 171             33.0             27          9.0         9  23.4
# 172            336.0             22         87.0         0  31.8
#
#      Underfive_Deaths   Polio  Diphtheria   HIV           GDP  Population  \
# 0                   83      6           65  0.1    584.259210  33736494.0
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Adult_Mortality    173 non-null    float64
#  1   Infant_Deaths      173 non-null    int64
#  2   Hepatitis B        164 non-null    float64
#  3   Measles            173 non-null    int64
#  4   BMI                171 non-null    float64
#  5   Underfive_Deaths   173 non-null    int64
#  6   Polio              173 non-null    int64
#  7   Diphtheria         173 non-null    int64
#  8   HIV                173 non-null    float64
#  9   GDP                152 non-null    float64
#  10  Population         139 non-null    float64
#  11  Malnourished10_19  171 non-null    float64
#  12  Malnourished5_9    171 non-null    float64
#  13  Income_Index       166 non-null    float64
#  14  Schooling          166 non-null    float64
#  15  Life_Expectancy    173 non-null    float64
# ...

# %%
data2.head(2)
# Out:
#    Adult_Mortality  Infant_Deaths  Hepatitis B  Measles    BMI  \
# 0            263.0             62         65.0      1154  19.1
# 1             74.0              0         99.0         0  58.0
#
#    Underfive_Deaths   Polio  Diphtheria   HIV         GDP  Population  \
# 0                 83      6           65  0.1   584.25921  33736494.0
# 1                  0     99           99  0.1  3954.22783     28873.0
#
#    Malnourished10_19  Malnourished5_9  Income_Index  Schooling  \
# 0               17.2             17.3         0.479       10.1
# 1                1.2              1.3         0.762       14.2
#
#    Life_Expectancy  Status_Developing
# 0             65.0                  1
# 1             77.8                  1

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer()

# %%
data3=imputer.fit_transform(data2)
data3=pd.DataFrame(data3,columns=data2.columns)
data3
# Out:
#      Adult_Mortality  Infant_Deaths  Hepatitis B  Measles    BMI  \
# 0              263.0           62.0         65.0    1154.0  19.1
# 1               74.0            0.0         99.0       0.0  58.0
# 2               19.0           21.0         95.0      63.0  59.5
# 3              335.0           66.0         64.0     118.0  23.3
# 4               13.0            0.0         99.0       0.0  47.7
# ..               ...            ...          ...       ...   ...
# 168            157.0            9.0         87.0       0.0  62.1
# 169            127.0           28.0         97.0     256.0  17.5
# 170            224.0           37.0         69.0     468.0  41.3
# 171             33.0           27.0          9.0       9.0  23.4
# 172            336.0           22.0         87.0       0.0  31.8
#
#      Underfive_Deaths   Polio  Diphtheria   HIV           GDP  Population  \
# 0                 83.0    6.0         65.0  0.1    584.259210  33736494.0
# ...

# %%
data3.isna().sum()
# Out:
# Adult_Mortality      0
# Infant_Deaths        0
# Hepatitis B          0
# Measles              0
# BMI                  0
# Underfive_Deaths     0
# Polio                0
# Diphtheria           0
# HIV                  0
# GDP                  0
# Population           0
# Malnourished10_19    0
# Malnourished5_9      0
# Income_Index         0
# Schooling            0
# Life_Expectancy      0
# Status_Developing    0
# dtype: int64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Are there any redundant features in the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

# %%
data3.columns
# Out:
# Index(['Adult_Mortality', 'Infant_Deaths', 'Hepatitis B', 'Measles ', 'BMI',
#        'Underfive_Deaths ', 'Polio', 'Diphtheria ', 'HIV', 'GDP', 'Population',
#        'Malnourished10_19', 'Malnourished5_9', 'Income_Index', 'Schooling',
#        'Life_Expectancy', 'Status_Developing'],
#       dtype='object')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Perform dummy encoding for appropriate variables of the dataset if required</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [raw]
# # type your code here
#
# Already did it as part of Feature engineering

# %% [markdown]
# <a id="lf"> </a>
# ## 2. Linear Regression

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5.  Build a full model on the given data. Check whether the obtained residuals have constant variance
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

# %%
inp=data3.drop('Life_Expectancy',1)
out=data3['Life_Expectancy']

# %%
inpc=sm.add_constant(inp)
ols=sm.OLS(out,inpc)
ols_mod=ols.fit()

# %%
#residue
residue=ols_mod.resid
residue
# Out:
# 0      4.892399
# 1      1.070306
# 2     -0.936964
# 3     -7.722198
# 4     -1.984155
#          ...
# 168   -0.689132
# 169    4.037767
# 170    3.068529
# 171   -3.515040
# 172    7.976049
# Length: 173, dtype: float64

# %%
ypred=ols_mod.predict(inpc)
ypred
# Out:
# 0      60.107601
# 1      76.729694
# 2      76.536964
# 3      60.122198
# 4      78.384155
#          ...
# 168    74.789132
# 169    71.962233
# 170    62.631471
# 171    65.315040
# 172    59.023951
# Length: 173, dtype: float64

# %%
#homoscadesity

sns.regplot(ypred,residue)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Build a model to study the impact of immunization on life expectancy, using least squares regression. Find the unexplained variation for the model
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data3.columns
# Out:
# Index(['Adult_Mortality', 'Infant_Deaths', 'Hepatitis B', 'Measles ', 'BMI',
#        'Underfive_Deaths ', 'Polio', 'Diphtheria ', 'HIV', 'GDP', 'Population',
#        'Malnourished10_19', 'Malnourished5_9', 'Income_Index', 'Schooling',
#        'Life_Expectancy', 'Status_Developing'],
#       dtype='object')

# %%
inp6=data3[['Hepatitis B','Polio','Diphtheria ']]
out=data3['Life_Expectancy']
inp6c=sm.add_constant(inp6)

# %%
ols=sm.OLS(out,inp6c)
ols_mod=ols.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_Expectancy   R-squared:                       0.342
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     29.29
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           2.65e-15
# Time:                        13:08:47   Log-Likelihood:                -569.20
# No. Observations:                 173   AIC:                             1146.
# Df Residuals:                     169   BIC:                             1159.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          53.9422      2.022     26.680      0.000      49.951      57.933
# ...

# %%
ypred=ols_mod.predict(inp6c)
ypred
# Out:
# 0      61.382706
# 1      75.222839
# 2      74.363016
# 3      61.389161
# 4      73.783665
#          ...
# 168    72.643370
# 169    74.792928
# 170    68.109931
# 171    55.876818
# 172    72.754075
# Length: 173, dtype: float64

# %%
sse=np.sum(np.square(out - ypred))
sse
# Out:
# 7300.839405060058

# %%
mse=np.sqrt(sse)
mse
# Out:
# 85.44494955853189

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Build a model to study the impact of malnutrition on life expectancy, using least squares regression. Interpret the coeffients</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data3.columns
# Out:
# Index(['Adult_Mortality', 'Infant_Deaths', 'Hepatitis B', 'Measles ', 'BMI',
#        'Underfive_Deaths ', 'Polio', 'Diphtheria ', 'HIV', 'GDP', 'Population',
#        'Malnourished10_19', 'Malnourished5_9', 'Income_Index', 'Schooling',
#        'Life_Expectancy', 'Status_Developing'],
#       dtype='object')

# %%
inp7=data3[['Malnourished10_19','Malnourished5_9']]
out=data3['Life_Expectancy']
inp7c=sm.add_constant(inp7)

# %%
ols=sm.OLS(out,inp7c)
ols_mod=ols.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_Expectancy   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     27.26
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           5.39e-11
# Time:                        13:08:51   Log-Likelihood:                -581.36
# No. Observations:                 173   AIC:                             1169.
# Df Residuals:                     170   BIC:                             1178.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# <a id="gd"> </a>
# ## 3. Gradient Descent

# %%
from sklearn.linear_model import SGDRegressor

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Build a model to study the influence of adult mortality rate on life expectancy using both the least squares regression and gradient descent approach. Are the fits for both the models different?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#ols model

ip=data3['Adult_Mortality']
op=data3['Life_Expectancy']
ipc=sm.add_constant(ip)

ols=sm.OLS(op,inpc)
ols_mod=ols.fit()
ols_mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_Expectancy   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     87.73
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           2.41e-69
# Time:                        14:48:32   Log-Likelihood:                -406.26
# No. Observations:                 173   AIC:                             846.5
# Df Residuals:                     156   BIC:                             900.1
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
data4=data3.copy()
data4
# Out:
#      Adult_Mortality  Infant_Deaths  Hepatitis B  Measles    BMI  \
# 0              263.0           62.0         65.0    1154.0  19.1
# 1               74.0            0.0         99.0       0.0  58.0
# 2               19.0           21.0         95.0      63.0  59.5
# 3              335.0           66.0         64.0     118.0  23.3
# 4               13.0            0.0         99.0       0.0  47.7
# ..               ...            ...          ...       ...   ...
# 168            157.0            9.0         87.0       0.0  62.1
# 169            127.0           28.0         97.0     256.0  17.5
# 170            224.0           37.0         69.0     468.0  41.3
# 171             33.0           27.0          9.0       9.0  23.4
# 172            336.0           22.0         87.0       0.0  31.8
#
#      Underfive_Deaths   Polio  Diphtheria   HIV           GDP  Population  \
# 0                 83.0    6.0         65.0  0.1    584.259210  33736494.0
# ...

# %%
inp=data4[['Adult_Mortality']]
opt=data4['Life_Expectancy']

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
# inp_c=ss.fit_transform(inp) as it was 1D will get error as it expects 2d array
inp_c=(inp-inp.mean())/inp.std()
opt_c=(opt-opt.mean())/opt.std()

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(inp_c,opt_c,test_size=0.2,random_state=10)

# %%
sgd=SGDRegressor()
sgd.fit(xtrain,ytrain)
ypred=sgd.predict(xtest)

# %%
from sklearn.metrics import r2_score,mean_squared_error
r2_score(ytest,ypred)
# Out:
# 0.4224957658176547

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Build a model to analyze the influence of immunization on life expectancy. Use SGD and plot a horizontal multiple barchart to compare the values of beta coefficients with values obtained by the full model build least squares regression.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sklearn LR and GD coeef and store it in DataFrame

coef_.plot(kind='plot')

# %%
data3.columns
# Out:
# Index(['Adult_Mortality', 'Infant_Deaths', 'Hepatitis B', 'Measles ', 'BMI',
#        'Underfive_Deaths ', 'Polio', 'Diphtheria ', 'HIV', 'GDP', 'Population',
#        'Malnourished10_19', 'Malnourished5_9', 'Income_Index', 'Schooling',
#        'Life_Expectancy', 'Status_Developing'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression

# %%
inp=data3[['Hepatitis B','Polio','Diphtheria ']] 
out=data3['Life_Expectancy']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(inp,out,test_size=0.3,random_state=10)

# %%
lr=LinearRegression()
lr.fit(xtrain,ytrain)
lrcoeff=lr.coef_
lrcoeff
# Out:
# array([-0.02332296,  0.1138534 ,  0.13199622])

# %%
plotting=pd.DataFrame()
plotting['LR_Coeff']=lrcoeff
plotting.index=inp.columns
plotting
# Out:
#              LR_Coeff
# Hepatitis B -0.023323
# Polio        0.113853
# Diphtheria   0.131996

# %%
sns.barplot(x=plotting.index,y=lrcoeff,data=plotting)
plt.show()

# %%
inpc=sm.add_constant(inp)
ols=sm.OLS(out,inpc)
ols_mod=ols.fit()
olscoeff=ols_mod.params
olscoeff
# Out:
# const          53.942216
# Hepatitis B    -0.038769
# Polio           0.110706
# Diphtheria      0.143019
# dtype: float64

# %%
plotting['ols_coeff']=olscoeff
plotting
# Out:
#              LR_Coeff  ols_coeff
# Hepatitis B -0.023323  -0.038769
# Polio        0.113853   0.110706
# Diphtheria   0.131996   0.143019

# %%
sns.barplot(x=plotting.index,y=plotting['ols_coeff'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Build a full model using least squares regression. Check whether the model overfits the training data or not.
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
inp=data3.drop('Life_Expectancy',1)
out=data3['Life_Expectancy']
inpc=sm.add_constant(inp)

# %%
olsmod=sm.OLS(out,inpc).fit()
olsmod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_Expectancy   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     87.73
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           2.41e-69
# Time:                        16:45:28   Log-Likelihood:                -406.26
# No. Observations:                 173   AIC:                             846.5
# Df Residuals:                     156   BIC:                             900.1
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
xtrain,xtest,ytrain,ytest=train_test_split(inpc,out,random_state=10,test_size=0.3)

# %%
ypred=olsmod.predict(xtest)
ypred
# Out:
# 112    60.964569
# 19     71.762620
# 68     70.656791
# 106    66.116798
# 66     69.189674
# 67     65.367838
# 90     73.101306
# 47     74.460053
# 10     75.684398
# 49     71.612465
# 149    83.483434
# 98     80.262929
# 59     75.374197
# 99     68.309621
# 169    71.962233
# 20     74.938428
# 81     75.072064
# 39     78.413642
# 111    71.493779
# 1      76.729694
# 76     81.204463
# 121    78.875981
# 140    60.072689
# 166    72.675389
# 102    71.483535
# 105    54.430959
# 72     71.091713
# 130    71.818951
# 110    81.815418
# 145    63.133057
# 136    83.279155
# 142    54.893830
# 163    79.974960
# 120    68.415746
# 26     60.274366
# 60     81.836751
# 55     80.757915
# 24     76.321985
# 58     61.640631
# 117    75.472959
# 21     69.379840
# 164    81.843703
# 61     66.215641
# 56     80.341400
# 159    71.529518
# 87     74.711648
# 91     77.604205
# 43     73.609676
# 146    72.510783
# 82     64.052729
# 135    58.321980
# 35     73.734089
# ...

# %%
mse=mean_squared_error(ytest,ypred)
# Out:
# 7.038912920486177

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 9.24364373818744

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Can we use a linear regression model to analyze how all features from the dataset impact life expectancy?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
inp=data3.drop('Life_Expectancy',1)
out=data3['Life_Expectancy']
inpc=sm.add_constant(inp)

olsmod=sm.OLS(out,inpc).fit()
olsmod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Life_Expectancy   R-squared:                       0.900
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     87.73
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           2.41e-69
# Time:                        16:49:33   Log-Likelihood:                -406.26
# No. Observations:                 173   AIC:                             846.5
# Df Residuals:                     156   BIC:                             900.1
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(inp.values,i) for i in range(inp.shape[1])]
vif['feature']=inp.columns
vif.sort_values('VIF',ascending=False)
# Out:
#            VIF            feature
# 13  179.641641       Income_Index
# 1   177.688009      Infant_Deaths
# 5   154.768252  Underfive_Deaths
# 14  150.943601          Schooling
# 7   116.013196        Diphtheria
# 2    84.141079        Hepatitis B
# 12   46.931504    Malnourished5_9
# 11   46.805632  Malnourished10_19
# 6    26.124492              Polio
# 4     9.837962                BMI
# 15    7.019415  Status_Developing
# 0     6.911560    Adult_Mortality
# 3     4.428202           Measles
# 8     2.381566                HIV
# 9     2.044278                GDP
# 10    1.688042         Population

# %% [markdown]
# <a id="reg"> </a>
# ## 4. Regularization

# %%
from sklearn.linear_model import Ridge,Lasso,ElasticNet

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Can we perform regression analysis without eliminating features involved in multicollinearity detected in question 11?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data3
# Out:
#      Adult_Mortality  Infant_Deaths  Hepatitis B  Measles    BMI  \
# 0              263.0           62.0         65.0    1154.0  19.1
# 1               74.0            0.0         99.0       0.0  58.0
# 2               19.0           21.0         95.0      63.0  59.5
# 3              335.0           66.0         64.0     118.0  23.3
# 4               13.0            0.0         99.0       0.0  47.7
# ..               ...            ...          ...       ...   ...
# 168            157.0            9.0         87.0       0.0  62.1
# 169            127.0           28.0         97.0     256.0  17.5
# 170            224.0           37.0         69.0     468.0  41.3
# 171             33.0           27.0          9.0       9.0  23.4
# 172            336.0           22.0         87.0       0.0  31.8
#
#      Underfive_Deaths   Polio  Diphtheria   HIV           GDP  Population  \
# 0                 83.0    6.0         65.0  0.1    584.259210  33736494.0
# ...

# %%
inp=data3.drop('Life_Expectancy',axis=1)
op=data3['Life_Expectancy']

# %%
mod_las=Lasso(alpha=0.1,normalize=True)
score=cross_val_score(mod_las,inp,op,cv=5,scoring='neg_mean_squared_error') 
score=np.sqrt(abs(score))
avg_score=np.mean(score)
variance=np.std(score)
coeffvariance=np.std(score)/np.mean(score)
res_las=avg_score,variance,coeffvariance
res_las
# Out:
# (3.149592915231401, 0.4398820598007126, 0.1396631474732646)

# %%
coef=pd.DataFrame()

# %%
mod_las=Lasso(alpha=0.1,normalize=True)
mod_las.fit(inp,out)
coef['Lasso_0.1']=mod_las.coef_

# %%
coef.index=inp.columns

# %%
coef
# Out:
#                    Lasso_150  Lasso_1  Lasso_0.1
# Adult_Mortality         -0.0     -0.0  -0.015032
# Infant_Deaths           -0.0     -0.0  -0.000000
# Hepatitis B              0.0      0.0   0.002394
# Measles                 -0.0     -0.0  -0.000000
# BMI                      0.0      0.0   0.000000
# Underfive_Deaths        -0.0     -0.0  -0.000000
# Polio                    0.0      0.0   0.000000
# Diphtheria               0.0      0.0   0.001351
# HIV                     -0.0     -0.0  -0.256773
# GDP                      0.0      0.0   0.000000
# Population              -0.0     -0.0  -0.000000
# Malnourished10_19       -0.0     -0.0  -0.000000
# Malnourished5_9         -0.0     -0.0  -0.000000
# Income_Index             0.0      0.0  31.202448
# Schooling                0.0      0.0   0.000000
# Status_Developing       -0.0     -0.0  -0.000000

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Build a model to study the impact of diseases and immunization on life expectancy. Identify the significant variables from the model. Use 'alpha = 1.5' if required.
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data3.columns
# Out:
# Index(['Adult_Mortality', 'Infant_Deaths', 'Hepatitis B', 'Measles ', 'BMI',
#        'Underfive_Deaths ', 'Polio', 'Diphtheria ', 'HIV', 'GDP', 'Population',
#        'Malnourished10_19', 'Malnourished5_9', 'Income_Index', 'Schooling',
#        'Life_Expectancy', 'Status_Developing'],
#       dtype='object')

# %%
inp=data3[['Measles ','HIV','Hepatitis B','Polio','Diphtheria ']]
out=data3['Life_Expectancy']

# %%
mod_rig=Ridge(alpha=0.02,normalize=True)
score=cross_val_score(mod_rig,inp,out,cv=5,scoring='r2')
score=np.sqrt(abs(score))
avg_score=np.mean(score)
variance=np.std(score)
coeffvar=np.std(score)/np.mean(score)
result=avg_score,variance,coeffvar
result
# Out:
# (0.6583427721733635, 0.06214602818293311, 0.09439767672662776)

# %%
coeff=pd.DataFrame()

# %%
mod_rig=Ridge(alpha=0.02,normalize=True)
mod_rig.fit(inp,out)
coeff['Ridge_0.02']=mod_rig.coef_

# %%
coeff.index=inp.columns

# %%
coeff
# Out:
#              Ridge_0.02
# Measles       -0.000084
# HIV           -2.509216
# Hepatitis B   -0.016452
# Polio          0.080562
# Diphtheria     0.073603

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Build a model to study the impact of malnutrition and diseases on life expectancy. Identify the insignificant variables from the model. Use 'alpha = 1' if required.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
data3.columns
# Out:
# Index(['Adult_Mortality', 'Infant_Deaths', 'Hepatitis B', 'Measles ', 'BMI',
#        'Underfive_Deaths ', 'Polio', 'Diphtheria ', 'HIV', 'GDP', 'Population',
#        'Malnourished10_19', 'Malnourished5_9', 'Income_Index', 'Schooling',
#        'Life_Expectancy', 'Status_Developing'],
#       dtype='object')

# %%
inp=data3[['Measles ','HIV','Malnourished10_19','Malnourished5_9']]
out=data3['Life_Expectancy']

# %%
mod_rig=Ridge(alpha=0.5,normalize=True)
score=cross_val_score(mod_rig,inp,out,cv=5,scoring='r2')
score=np.sqrt(abs(score))
avg_score=np.mean(score)
variance=np.std(score)
coeffvar=np.std(score)/np.mean(score)
result=avg_score,variance,coeffvar
result
# Out:
# (0.654446208604407, 0.05254751443114109, 0.08029309932621899)

# %%
coeff=pd.DataFrame()
mod_rig=Ridge(alpha=0.02,normalize=True)
mod_rig.fit(inp,out)
coeff['Ridge_0.5']=mod_rig.coef_
coeff.index=inp.columns

# %%
coeff
# Out:
#                    Ridge_0.5
# Measles             0.000043
# HIV                -3.090701
# Malnourished10_19  -0.214042
# Malnourished5_9    -0.568672

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Build a full model using the elastic net regression. Use 'alpha = 0.1' and 'l1_ratio=0.001'. Also, compute the RMSE for train and test sets.
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
inp=data3.drop('Life_Expectancy',axis=1)
op=data3['Life_Expectancy']

mod_enet=ElasticNet(alpha=0.007,normalize=True)
score=cross_val_score(mod_enet,inp,out,cv=5,scoring='neg_mean_squared_error') 
score=np.sqrt(abs(score))
avg_score=np.mean(score)
variance=np.std(score)
coeffvariance=np.std(score)/np.mean(score)
res_enet=avg_score,variance,coeffvariance
res_enet
# Out:
# (3.1182122967163814, 0.2919611527503939, 0.09363094137555747)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Build a full model. Identify the features that are significantly influencing the life expectancy. Use 'alpha = 0.5' if required. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
inp=data3.drop('Life_Expectancy',axis=1)
op=data3['Life_Expectancy']

mod_enet=ElasticNet(alpha=0.0025,normalize=True)
score=cross_val_score(mod_enet,inp,out,cv=5,scoring='neg_mean_squared_error') 
score=np.sqrt(abs(score))
avg_score=np.mean(score)
variance=np.std(score)
coeffvariance=np.std(score)/np.mean(score)
res_enet=avg_score,variance,coeffvariance
res_enet
# Out:
# (2.928055727511375, 0.2733641271633443, 0.09336028839713478)

# %% [markdown]
# <a id="gs"> </a>
# ## 5. Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. If ridge regression is used to build a full model. Which value is the best alpha from the list of values?<br><br>Consider the alpha values: [7,8,9,10,11]</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
inp=data3.drop('Life_Expectancy',axis=1)
op=data3['Life_Expectancy']

# %%
# type your code here
param={'alpha':[7,8,9,10,11]}
rid=Ridge(normalize=True)
grid=GridSearchCV(rid,param_grid=param,scoring='r2',cv=5)

# %%
mod_grid=grid.fit(inp,op)
mod_grid.best_params_
# Out:
# {'alpha': 7}

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. If lasso regression is used to build a full model. Which value is the best alpha from the list of values?<br><br>Consider the alpha values: [7,8,9,10,11]</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
param={'alpha':[7,8,9,10,11]}
las=Lasso(normalize=True)
grid=GridSearchCV(las,param_grid=param,scoring='r2',cv=5)
mod_grid=grid.fit(inp,op)
mod_grid.best_params_
# Out:
# {'alpha': 7}

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Perform regression analysis to study the impact of malnutrition and diseases on life expectancy. Determine the optimal value of alpha and mixing parameter if elastic net regression is used to build the model. Consider the following list of values:<br><br> alpha : [0.1,0.5,1,1.5,2,2.5,3,3.5,4]<br> l1_ratio : [0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9] </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
inp=data3[['Measles ','HIV','Malnourished10_19','Malnourished5_9']]
out=data3['Life_Expectancy']

# %%
param={'alpha':[0.1,0.5,1,1.5,2,2.5,3,3.5,4],'l1_ratio': [0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9]}
enet=ElasticNet(normalize=True)
grid=GridSearchCV(enet,param_grid=param,scoring='r2',cv=5)
mod_grid=grid.fit(inp,op)
mod_grid.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 0.9}

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Build a full model. Select the optimal value for elastic net mixing parameter if the alpha value is 0.8<br><br>Consider the values: l1_ratio : [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1]</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
inp=data3.drop('Life_Expectancy',axis=1)
out=data3['Life_Expectancy']

# %%
param={'alpha':[0.8],'l1_ratio': [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1]}
enet=ElasticNet(normalize=True)
grid=GridSearchCV(enet,param_grid=param,scoring='r2',cv=5)
mod_grid=grid.fit(inp,op)
mod_grid.best_params_
# Out:
# {'alpha': 0.8, 'l1_ratio': 0.001}
